# %% [markdown]
# <a href="https://colab.research.google.com/github/harsh903/Hate-Speech-and-Offensive-Language-Detection-Project-/blob/main/Hate_Speech_and_Offensive_Language_Detection_Project_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Your paragraph text.png](data:image/png;base64,...)
#
#
# Hate speech detection is an important tool for combating hate speech, particularly on social media. Several methods have been developed for the task, including a recent proliferation of machine-learning and deep-learning model-based approaches. Because hate speech data sets are rarely clean, they must be pre-processed before classification algorithms can detect hate speech. Different machine learning models have different strengths, making some better than others at certain tasks like detecting hate speech. Some models are more accurate than others in terms of efficiency. It is critical to employ various models and compare their performance in order to identify the best one for hate speech detection. Pre-training methods have grown in popularity in recent years, and it is important to test whether they work well with hate speech detection algorithms. It is also important to see how hate speech detection models can be used to address domain changes.

# %%
import numpy as np # basic Libraries  
import pandas as pd 
import seaborn as sns
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import re # regular expression module 
stemmer = nltk.SnowballStemmer("english") # for stemming 
from nltk.corpus import stopwords
import string
stopword=set(stopwords.words('english')) # for stopword

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.stem import LancasterStemmer,WordNetLemmatizer
import re, string, unicodedata
from string import punctuation

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud # module for wordcloud

# %%
df = pd.read_csv("/content/drive/MyDrive/labeled_data.csv") # data reading

# %%
df.head()
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
df.shape
# Out:
# (24783, 7)

# %%
df.isnull().sum() # null value in data
# Out:
# Unnamed: 0            0
# count                 0
# hate_speech           0
# offensive_language    0
# neither               0
# class                 0
# tweet                 0
# dtype: int64

# %%
# dataframe transformation 
df.drop(df.columns[[0,1,2,3,4]], axis=1, inplace=True)
  
df
# Out:
#        class                                              tweet
# 0          2  !!! RT @mayasolovely: As a woman you shouldn't...
# 1          1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2          1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3          1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4          1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...      ...                                                ...
# 24778      1  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779      2  you've gone and broke the wrong heart baby, an...
# 24780      1  young buck wanna eat!!.. dat nigguh like I ain...
# 24781      1              youu got wild bitches tellin you lies
# 24782      2  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [24783 rows x 2 columns]

# %%
sns.countplot('class',data=df) # count of class in data
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
hate, offensive, neither = np.bincount(df['class']) # percentage of class in data
total = hate + offensive + neither
print('Class 0:\n    Total: {}\n    hate: {} ({:.2f}% of total)\n'.format(
    total, hate, 100 * hate / total))
print('Class 1:\n    Total: {}\n    Offensive: {} ({:.2f}% of total)\n'.format(
    total, offensive, 100 * offensive / total))
print('Class 2:\n    Total: {}\n    Neither: {} ({:.2f}% of total)\n'.format(
    total, neither, 100 * neither / total))
# Out:
# Class 0:
#     Total: 24783
#     hate: 1430 (5.77% of total)
#
# Class 1:
#     Total: 24783
#     Offensive: 19190 (77.43% of total)
#
# Class 2:
#     Total: 24783
#     Neither: 4163 (16.80% of total)

# %%
classes = ['Hate', ' Offensive','Neither']
Total = [1430,19190,4163]
fig = plt.figure(figsize =(10, 7))
plt.pie(Total, labels = classes)
plt.show()

# %%
'''def clean_text(text):  # data cleaning funtion
    text = str(text).lower() # lower the text
    text = re.sub('\[.*?\]', '', text) # removing puncatuation
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword] # removing stopword
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')] # stemming
    text=" ".join(text)
    return text '''

# %%
def hapus_url(text):
    return re.sub(r'http\S+','', text)
def remove_special_characters(text, remove_digits=True):
    pattern=r'[^a-zA-Z0-9\s]'
    text=re.sub(pattern,'',text)
    return text
def stemmer(text):
    ps=nltk.porter.PorterStemmer()
    text=' '.join([ps.stem(word) for word in text.split()])
    return text

def final_clean(text):
    final_text= []
    for i in text.split():
        if i.strip().lower() not in stopword and i.strip().lower().isalpha():
            final_text.append(i.strip().lower())
    return " ".join(final_text)

# %%
def clean(text):
    text = hapus_url(text)
    text = remove_special_characters(text, remove_digits=True)
    text = stemmer(text)
    text = final_clean(text)
    return text

# %%
df['tweet'] = df['tweet'].apply(clean)

# %%
#df1['text']=df1['text'].apply(clean_text) # apply the function on text

# %%
df.tail()
# Out:
#        class                                              tweet
# 24778      1  muthafin lie coreyemanuel right hi tl trash mi...
# 24779      2  youv gone broke wrong heart babi drove redneck...
# 24780      1  young buck wanna eat dat nigguh like aint fuck...
# 24781      1                     youu got wild bitch tellin lie
# 24782      2  ruffl ntac eileen dahlia beauti color combin p...

# %%
text = " ".join(cat for cat in df.tweet) # joining of all sentence in variable text

# %%
top_N =  20 # top 20 frequent sentence in data
word_dist = nltk.FreqDist(df['tweet'])
print('All frequencies')
print('='*60)
rslt=pd.DataFrame(word_dist.most_common(top_N),columns=['sentence','Frequency'])

print(rslt)
print ('='*60)
# Out:
# All frequencies
# ============================================================
#                                              sentence  Frequency
# 0                                               bitch         25
# 1                                                 hoe         15
# 2                                               pussi         14
# 3           best asian massag park slope top rate spa         14
# 4                                              faggot         10
# 5                                      hoe aint loyal          8
# 6          grand open top class orient massag perfect          8
# 7                           bad bitch onli thing like          7
# 8                                          fuck bitch          6
# 9   best asian massag brooklyn park slope top rate...          5
# 10                                                fag          5
# 11                                      dont love hoe          5
# 12                                  rt hoe aint loyal          5
# 13                                          thi bitch          5
# 14                                                             4
# 15                                              trash          4
# 16                                             retard          4
# 17                                        littl bitch          4
# 18                                        karma bitch          4
# 19                                         need bitch          4
# ============================================================

# %%
df.tweet.str.split(expand=True).stack().value_counts() # word frequency
# Out:
# bitch                     11180
# rt                         7584
# hoe                        4204
# like                       2843
# fuck                       2238
#                           ...
# boister                       1
# belliger                      1
# damnismartallofasudden        1
# zigeun                        1
# coll                          1
# Length: 25283, dtype: int64

# %%
# wordcloud chart
wordcloud = WordCloud(width = 600, height = 600,
                background_color ='white',
                stopwords = stopword,
                min_font_size = 10).generate(text)
 
# plot the WordCloud image                      
plt.figure(figsize = (5, 5), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %% [markdown]
# ## Word2vec

# %% [markdown]
# TF-IDF

# %%
x = df['tweet']
y = df['class']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25,random_state=0,stratify=y)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
Tfidf_vect = TfidfVectorizer()
Tfidf_vect.fit(x)
xv_train = Tfidf_vect.transform(x_train)
xv_test = Tfidf_vect.transform(x_test)

# %%
("n_samples: %d, n_features: %d" % xv_train.shape)
# Out:
# 'n_samples: 18587, n_features: 25265'

# %%
xv_train.shape,y_train.shape
# Out:
# ((18587, 25265), (18587,))

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# Undersampling

# %%
'''class_0 = df[df['class'] == 0]
class_1 = df[df['class'] == 1]
class_2 = df[df['class'] == 2]'''

# %%
#class_0.shape,class_1.shape,class_2.shape
# Out:
# ((1430, 2), (19190, 2), (4163, 2))

# %%
#n = len(class_0)

# %%
'''df_class_1_under = class_1.sample(n)
df_class_2_under = class_2.sample(n)
data = pd.concat([class_0,df_class_1_under,df_class_2_under], axis=0)

print('Random under-sampling:')
print(data['class'].value_counts())'''
# Out:
# Random under-sampling:
# 0    1430
# 1    1430
# 2    1430
# Name: class, dtype: int64

# %% [markdown]
# **Oversampling**

# %%
#df['class'].value_counts()
# Out:
# 1    19190
# 2     4163
# 0     1430
# Name: class, dtype: int64

# %%
#count_class_1 = len(class_1)

# %%
# Oversample 1-class and concat the DataFrames of both classes
'''class_0_over = class_0.sample(count_class_1, replace=True)
class_2_over = class_2.sample(count_class_1, replace=True)
df_over = pd.concat([class_0_over, class_1,class_2_over], axis=0)

print('Random over-sampling:')
print(df_over['class'].value_counts())'''
# Out:
# "class_0_over = class_0.sample(count_class_1, replace=True)\nclass_2_over = class_2.sample(count_class_1, replace=True)\ndf_over = pd.concat([class_0_over, class_1,class_2_over], axis=0)\n\nprint('Random over-sampling:')\nprint(df_over['class'].value_counts())"

# %%
#df_over.shape, df.shape

# %% [markdown]
# SMOTE

# %%
df['class'].value_counts()
# Out:
# 1    19190
# 2     4163
# 0     1430
# Name: class, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()
x_train, y_train = oversample.fit_resample(xv_train, y_train)
y_train.value_counts()
# Out:
# 2    14392
# 1    14392
# 0    14392
# Name: class, dtype: int64

# %%
x_test, y_test = oversample.fit_resample(xv_test, y_test)
y_test.value_counts()
# Out:
# 1    4798
# 2    4798
# 0    4798
# Name: class, dtype: int64

# %% [markdown]
# SVM-SMOTE

# %%
'''from imblearn.over_sampling import SVMSMOTE
svmsmote = SVMSMOTE(random_state = 101)'''
# Out:
# 'from imblearn.over_sampling import SVMSMOTE\nsvmsmote = SVMSMOTE(random_state = 101)'

# %%
#x_train2, y_train2 = svmsmote.fit_resample(xv_train, y_train)

# %%
#x_test2, y_test2 = svmsmote.fit_resample(xv_test, y_test)

# %%
#y_train2.value_counts()

# %%
#y_test2.value_counts()

# %% [markdown]
# # Model Training

# %% [markdown]
# **Logistic** Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
log = LogisticRegression()
log.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
perd_log=log.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,perd_log)
# Out:
# array([[2942, 1588,  268],
#        [ 425, 4157,  216],
#        [  60,  162, 4576]])

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, perd_log, labels=log.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=log.classes_)
disp.plot()

# %%
print(classification_report(perd_log, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.86      0.72      3427
#            1       0.87      0.70      0.78      5907
#            2       0.95      0.90      0.93      5060
#
#     accuracy                           0.81     14394
#    macro avg       0.81      0.82      0.81     14394
# weighted avg       0.84      0.81      0.82     14394

# %%
from yellowbrick.classifier import PrecisionRecallCurve

# %%
viz = PrecisionRecallCurve(log)
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
viz = PrecisionRecallCurve(log,
    per_class=True,
    cmap="Set1")
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/yellowbrick/classifier/prcurve.py:257: YellowbrickWarning: micro=True is ignored;specify per_class=False to draw a PR curve after micro-averaging
#   YellowbrickWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
from yellowbrick.classifier import ROCAUC

def plot_ROC_curve(model, x_train ,y_train, x_test, y_test):

    # Creating visualization with the readable labels
    visualizer = ROCAUC(model, encoder={0: 'hate', 
                                        1: 'Offensive', 
                                        2: 'neither'})
                                        
    # Fitting to the training data first then scoring with the test data                                    
    visualizer.fit(x_train, y_train)
    visualizer.score(x_test, y_test)
    visualizer.show()
    
    return visualizer

# %%
plot_ROC_curve(log, x_train ,y_train, x_test, y_test)
# Out:
# ROCAUC(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7f164154a810>,
#        encoder={0: 'hate', 1: 'Offensive', 2: 'neither'},
#        estimator=LogisticRegression())

# %%
# Logistic Model hyperparameter

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

# %%
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]

# %%
grid = dict(solver=solvers,penalty=penalty,C=c_values)

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %%
grid_search = GridSearchCV(estimator=log, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.958381 using {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.000000 (0.000000) with: {'C': 100, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 100, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.958381 (0.003110) with: {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.953338 (0.002926) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.955386 (0.002628) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.955656 (0.003075) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.000000 (0.000000) with: {'C': 10, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 10, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.956071 (0.002917) with: {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.951113 (0.002655) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.951105 (0.002781) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.948256 (0.003024) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.000000 (0.000000) with: {'C': 1.0, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 1.0, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.916278 (0.004378) with: {'C': 1.0, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.927158 (0.003890) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.927150 (0.003880) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.913868 (0.004090) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.000000 (0.000000) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.824024 (0.005997) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.871841 (0.004977) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.871864 (0.004961) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.860268 (0.004689) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.000000 (0.000000) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'newton-cg'}
# 0.000000 (0.000000) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.740756 (0.005656) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.823801 (0.005578) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.823808 (0.005577) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.815539 (0.005376) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
log_hype = LogisticRegression(C = 100, penalty = 'l1', solver = 'liblinear')
log_hype.fit(x_train, y_train)
# Out:
# LogisticRegression(C=100, penalty='l1', solver='liblinear')

# %%
perd_log_hype =log_hype.predict(x_test)

# %%
print(classification_report(perd_log_hype, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.41      0.79      0.54      2494
#            1       0.88      0.55      0.68      7672
#            2       0.83      0.94      0.88      4228
#
#     accuracy                           0.71     14394
#    macro avg       0.71      0.76      0.70     14394
# weighted avg       0.78      0.71      0.71     14394

# %%
confusion_matrix(y_test,perd_log_hype)
# Out:
# array([[1960, 2707,  131],
#        [ 426, 4242,  130],
#        [ 108,  723, 3967]])

# %%
cm = confusion_matrix(y_test, perd_log_hype, labels=log_hype.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=log_hype.classes_)
disp.plot()

# %%
viz = PrecisionRecallCurve(log_hype)
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()

# %%
viz = PrecisionRecallCurve(log_hype,
    per_class=True,
    cmap="Set1")
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/yellowbrick/classifier/prcurve.py:257: YellowbrickWarning: micro=True is ignored;specify per_class=False to draw a PR curve after micro-averaging
#   YellowbrickWarning,

# %%
plot_ROC_curve(log_hype, x_train ,y_train, x_test, y_test)
# Out:
# ROCAUC(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7f1641b7b450>,
#        encoder={0: 'hate', 1: 'Offensive', 2: 'neither'},
#        estimator=LogisticRegression(C=100, penalty='l1', solver='liblinear'))

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
pred_svm = model.predict(x_test)

# %%
confusion_matrix(y_test,pred_svm)
# Out:
# array([[3578,  890,  330],
#        [  40, 4645,  113],
#        [  45,  249, 4504]])

# %%
cm = confusion_matrix(y_test, pred_svm, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model.classes_)
disp.plot()

# %%
print(classification_report(pred_svm, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.98      0.85      3663
#            1       0.97      0.80      0.88      5784
#            2       0.94      0.91      0.92      4947
#
#     accuracy                           0.88     14394
#    macro avg       0.88      0.90      0.88     14394
# weighted avg       0.90      0.88      0.89     14394

# %%
viz = PrecisionRecallCurve(model)
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()

# %%
viz = PrecisionRecallCurve(model,
    per_class=True,
    cmap="Set1")
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/yellowbrick/classifier/prcurve.py:257: YellowbrickWarning: micro=True is ignored;specify per_class=False to draw a PR curve after micro-averaging
#   YellowbrickWarning,

# %%
plot_ROC_curve(model, x_train ,y_train, x_test, y_test)
# Out:
# ROCAUC(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7f1641b96490>,
#        encoder={0: 'hate', 1: 'Offensive', 2: 'neither'}, estimator=SVC())

# %% [markdown]
# SVC hyperparameter

# %%
# grid search
'''param_grid = {'C': [0.1, 1], 
              'gamma': [1, 0.1],
              'kernel': [ 'rbf', 'sigmoid']} 
grid = GridSearchCV(model, param_grid, refit = True, verbose = 3)
grid.fit(x_train, y_train)'''
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.571 total time= 2.4min
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.948 total time= 3.1min
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.960 total time= 2.7min
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.959 total time= 2.6min
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.957 total time= 3.0min
# [CV 1/5] END ....C=0.1, gamma=1, kernel=sigmoid;, score=0.862 total time= 2.5min
# [CV 2/5] END ....C=0.1, gamma=1, kernel=sigmoid;, score=0.876 total time= 2.6min
# [CV 3/5] END ....C=0.1, gamma=1, kernel=sigmoid;, score=0.870 total time= 2.5min
# [CV 4/5] END ....C=0.1, gamma=1, kernel=sigmoid;, score=0.875 total time= 2.5min
# [CV 5/5] END ....C=0.1, gamma=1, kernel=sigmoid;, score=0.877 total time= 2.5min
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.760 total time= 3.8min
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.869 total time= 4.4min
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.871 total time= 4.0min
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.872 total time= 4.0min
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.875 total time= 4.0min
# [CV 1/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.776 total time= 4.2min
# [CV 2/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.782 total time= 4.5min
# [CV 3/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.779 total time= 4.3min
# [CV 4/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.785 total time= 4.2min
# [CV 5/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.788 total time= 4.2min
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.805 total time= 2.1min
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.975 total time= 3.4min
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.978 total time= 3.3min
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.978 total time= 3.4min
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.979 total time= 3.2min
# [CV 1/5] END ......C=1, gamma=1, kernel=sigmoid;, score=0.905 total time= 1.3min
# [CV 2/5] END ......C=1, gamma=1, kernel=sigmoid;, score=0.910 total time= 1.3min
# [CV 3/5] END ......C=1, gamma=1, kernel=sigmoid;, score=0.909 total time= 1.4min
# [CV 4/5] END ......C=1, gamma=1, kernel=sigmoid;, score=0.914 total time= 1.4min
# [CV 5/5] END ......C=1, gamma=1, kernel=sigmoid;, score=0.920 total time= 1.4min
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.869 total time= 1.9min
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.947 total time= 2.0min
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.948 total time= 2.0min
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.951 total time= 2.0min
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.951 total time= 2.0min
# [CV 1/5] END ....C=1, gamma=0.1, kernel=sigmoid;, score=0.873 total time= 2.4min
# [CV 2/5] END ....C=1, gamma=0.1, kernel=sigmoid;, score=0.882 total time= 2.5min
# [CV 3/5] END ....C=1, gamma=0.1, kernel=sigmoid;, score=0.879 total time= 2.5min
# [CV 4/5] END ....C=1, gamma=0.1, kernel=sigmoid;, score=0.884 total time= 2.5min
# [CV 5/5] END ....C=1, gamma=0.1, kernel=sigmoid;, score=0.885 total time= 2.6min
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1], 'gamma': [1, 0.1],
#                          'kernel': ['rbf', 'sigmoid']},
#              verbose=3)

# %%
#print(grid.best_params_)
# Out:
# {'C': 1, 'gamma': 1, 'kernel': 'rbf'}

# %%
#print(grid.best_estimator_)
# Out:
# SVC(C=1, gamma=1)

# %%
model_hype = SVC(C=1, gamma=1,kernel ='rbf')
model_hype.fit(x_train,y_train)
# Out:
# SVC(C=1, gamma=1)

# %%
pred_svm_hype = model_hype.predict(x_test)

# %%
confusion_matrix(y_test,pred_svm_hype)
# Out:
# array([[3682,  778,  338],
#        [  53, 4630,  115],
#        [  53,  204, 4541]])

# %%
cm = confusion_matrix(y_test, pred_svm_hype, labels=model_hype.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels = model_hype.classes_)
disp.plot()

# %%
print(classification_report(pred_svm_hype, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.97      0.86      3788
#            1       0.96      0.83      0.89      5612
#            2       0.95      0.91      0.93      4994
#
#     accuracy                           0.89     14394
#    macro avg       0.89      0.90      0.89     14394
# weighted avg       0.91      0.89      0.89     14394

# %%
viz = PrecisionRecallCurve(model_hype)
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()

# %%
viz = PrecisionRecallCurve(model_hype,
    per_class=True,
    cmap="Set1")
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/yellowbrick/classifier/prcurve.py:257: YellowbrickWarning: micro=True is ignored;specify per_class=False to draw a PR curve after micro-averaging
#   YellowbrickWarning,

# %%
plot_ROC_curve(model_hype, x_train ,y_train, x_test, y_test)
# Out:
# ROCAUC(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7f1641c37bd0>,
#        encoder={0: 'hate', 1: 'Offensive', 2: 'neither'},
#        estimator=SVC(C=1, gamma=1))

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier= DecisionTreeClassifier(criterion='entropy', random_state=45)  
classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=45)

# %%
pred_tre = classifier.predict(x_test)

# %%
confusion_matrix(y_test,pred_tre)
# Out:
# array([[3043, 1553,  202],
#        [ 275, 4359,  164],
#        [ 180,  387, 4231]])

# %%
cm = confusion_matrix(y_test, pred_tre, labels=classifier.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=classifier.classes_)
disp.plot()

# %%
print(classification_report(pred_tre, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.87      0.73      3498
#            1       0.91      0.69      0.79      6299
#            2       0.88      0.92      0.90      4597
#
#     accuracy                           0.81     14394
#    macro avg       0.81      0.83      0.81     14394
# weighted avg       0.83      0.81      0.81     14394

# %%
viz = PrecisionRecallCurve(classifier)
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()

# %%
viz = PrecisionRecallCurve(classifier,
    per_class=True,
    cmap="Set1")
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/yellowbrick/classifier/prcurve.py:257: YellowbrickWarning: micro=True is ignored;specify per_class=False to draw a PR curve after micro-averaging
#   YellowbrickWarning,

# %%
plot_ROC_curve(classifier, x_train ,y_train, x_test, y_test)
# Out:
# ROCAUC(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7f164155bc90>,
#        encoder={0: 'hate', 1: 'Offensive', 2: 'neither'},
#        estimator=DecisionTreeClassifier(criterion='entropy', random_state=45))

# %% [markdown]
# Decision Tree Hyperparametre

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Create the parameter grid based on the results of random search 
params = {
    'max_depth': [2, 3, 5, 10],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'criterion': ["gini", "entropy"]
}

# %%
grid_search = GridSearchCV(estimator=classifier, 
                           param_grid=params, 
                           cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 4 folds for each of 40 candidates, totalling 160 fits
# GridSearchCV(cv=4,
#              estimator=DecisionTreeClassifier(criterion='entropy',
#                                               random_state=45),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 10],
#                          'min_samples_leaf': [5, 10, 20, 50, 100]},
#              scoring='accuracy', verbose=1)

# %%
print(grid_search.best_params_)
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5}

# %%
classifier_hype = DecisionTreeClassifier(criterion='entropy', max_depth = 10, min_samples_leaf= 5)  
classifier_hype.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf=5)

# %%
pred_tre_hype = classifier_hype.predict(x_test)

# %%
confusion_matrix(y_test,pred_tre_hype)
# Out:
# array([[3018,  822,  958],
#        [ 373, 3849,  576],
#        [  59,   58, 4681]])

# %%
cm = confusion_matrix(y_test, pred_tre_hype, labels=classifier_hype.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=classifier_hype.classes_)
disp.plot()

# %%
print(classification_report(pred_tre_hype, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.87      0.73      3450
#            1       0.80      0.81      0.81      4729
#            2       0.98      0.75      0.85      6215
#
#     accuracy                           0.80     14394
#    macro avg       0.80      0.81      0.80     14394
# weighted avg       0.84      0.80      0.81     14394

# %%
viz = PrecisionRecallCurve(classifier_hype)
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()

# %%
viz = PrecisionRecallCurve(classifier_hype,
    per_class=True,
    cmap="Set1")
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/yellowbrick/classifier/prcurve.py:257: YellowbrickWarning: micro=True is ignored;specify per_class=False to draw a PR curve after micro-averaging
#   YellowbrickWarning,

# %%
plot_ROC_curve(classifier_hype, x_train ,y_train, x_test, y_test)
# Out:
# ROCAUC(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7f164160b350>,
#        encoder={0: 'hate', 1: 'Offensive', 2: 'neither'},
#        estimator=DecisionTreeClassifier(criterion='entropy', max_depth=10,
#                                         min_samples_leaf=5))

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
ran=RandomForestClassifier(n_estimators=100)
ran.fit(x_train,y_train)
perd_ran=ran.predict(x_test)

# %%
confusion_matrix(y_test,perd_ran)
# Out:
# array([[2847, 1717,  234],
#        [ 173, 4488,  137],
#        [  64,  307, 4427]])

# %%
cm = confusion_matrix(y_test, perd_ran, labels=ran.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=ran.classes_)
disp.plot()

# %%
print(classification_report(perd_ran, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.92      0.72      3084
#            1       0.94      0.69      0.79      6512
#            2       0.92      0.92      0.92      4798
#
#     accuracy                           0.82     14394
#    macro avg       0.82      0.85      0.81     14394
# weighted avg       0.86      0.82      0.82     14394

# %%
viz = PrecisionRecallCurve(ran)
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()

# %%
viz = PrecisionRecallCurve(ran,
    per_class=True,
    cmap="Set1")
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/yellowbrick/classifier/prcurve.py:257: YellowbrickWarning: micro=True is ignored;specify per_class=False to draw a PR curve after micro-averaging
#   YellowbrickWarning,

# %%
plot_ROC_curve(ran, x_train ,y_train, x_test, y_test)
# Out:
# ROCAUC(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7f164155d650>,
#        encoder={0: 'hate', 1: 'Offensive', 2: 'neither'},
#        estimator=RandomForestClassifier())

# %% [markdown]
# # Ensemble Learning Model

# %% [markdown]
# Algorithms based on Bagging and Boosting

# %% [markdown]
# Xgboost Model

# %%
import xgboost as xgb

# %%
xgb_classifier = xgb.XGBClassifier()
xgb_classifier.fit(x_train,y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
pred_xg = xgb_classifier.predict(x_test)

# %%
confusion_matrix(y_test,pred_xg)
# Out:
# array([[3503,  632,  663],
#        [ 318, 3968,  512],
#        [  80,   49, 4669]])

# %%
cm = confusion_matrix(y_test, pred_xg, labels=xgb_classifier.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=xgb_classifier.classes_)
disp.plot()

# %%
print(classification_report(pred_xg, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.90      0.81      3901
#            1       0.83      0.85      0.84      4649
#            2       0.97      0.80      0.88      5844
#
#     accuracy                           0.84     14394
#    macro avg       0.84      0.85      0.84     14394
# weighted avg       0.86      0.84      0.85     14394

# %%
plot_ROC_curve(xgb_classifier, x_train ,y_train, x_test, y_test)
# Out:
# ROCAUC(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7f1641fc6c90>,
#        encoder={0: 'hate', 1: 'Offensive', 2: 'neither'},
#        estimator=XGBClassifier(objective='multi:softprob'))

# %% [markdown]
# AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
model_ada = AdaBoostClassifier(random_state=1)
model_ada.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(random_state=1)

# %%
predict_ada = model_ada.predict(x_test)

# %%
confusion_matrix(y_test,predict_ada)
# Out:
# array([[3175, 1085,  538],
#        [ 467, 4027,  304],
#        [ 126,   98, 4574]])

# %%
print(classification_report(predict_ada, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.84      0.74      3768
#            1       0.84      0.77      0.80      5210
#            2       0.95      0.84      0.90      5416
#
#     accuracy                           0.82     14394
#    macro avg       0.82      0.82      0.81     14394
# weighted avg       0.84      0.82      0.82     14394

# %%
viz = PrecisionRecallCurve(model_ada)
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()

# %%
viz = PrecisionRecallCurve(model_ada,
    per_class=True,
    cmap="Set1")
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/yellowbrick/classifier/prcurve.py:257: YellowbrickWarning: micro=True is ignored;specify per_class=False to draw a PR curve after micro-averaging
#   YellowbrickWarning,

# %%
plot_ROC_curve(model_ada, x_train ,y_train, x_test, y_test)
# Out:
# ROCAUC(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7f1641aa5210>,
#        encoder={0: 'hate', 1: 'Offensive', 2: 'neither'},
#        estimator=AdaBoostClassifier(random_state=1))

# %% [markdown]
# Gradient Boosting Classifier Model

# %%
from sklearn.ensemble import GradientBoostingClassifier
model_gra = GradientBoostingClassifier(learning_rate=0.01,random_state=1)
model_gra.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, random_state=1)

# %%
predict_gra = model_gra.predict(x_test)

# %%
confusion_matrix(y_test,predict_gra)
# Out:
# array([[2601,  758, 1439],
#        [ 328, 3787,  683],
#        [  37,   55, 4706]])

# %%
print(classification_report(predict_gra, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.88      0.67      2966
#            1       0.79      0.82      0.81      4600
#            2       0.98      0.69      0.81      6828
#
#     accuracy                           0.77     14394
#    macro avg       0.77      0.80      0.76     14394
# weighted avg       0.83      0.77      0.78     14394

# %%
viz = PrecisionRecallCurve(model_gra)
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()

# %%
viz = PrecisionRecallCurve(model_gra,
    per_class=True,
    cmap="Set1")
viz.fit(x_train, y_train)
viz.score(x_test, y_test)
viz.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/yellowbrick/classifier/prcurve.py:257: YellowbrickWarning: micro=True is ignored;specify per_class=False to draw a PR curve after micro-averaging
#   YellowbrickWarning,

# %%
plot_ROC_curve(model_gra, x_train ,y_train, x_test, y_test)
# Out:
# ROCAUC(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7f1641ad09d0>,
#        encoder={0: 'hate', 1: 'Offensive', 2: 'neither'},
#        estimator=GradientBoostingClassifier(learning_rate=0.01, random_state=1))

# %% [markdown]
# # Prediction

# %% [markdown]
# Best Model

# %%
from sklearn.svm import SVC
model_best = SVC(C=1, gamma=1,kernel ='rbf')
model_best.fit(x_train,y_train)
# Out:
# SVC(C=1, gamma=1)

# %%
pred_svm = model_best.predict(x_test)

# %%
cm = confusion_matrix(y_test, pred_svm, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=model.classes_)
disp.plot()

# %%
print(classification_report(pred_svm, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.97      0.86      3788
#            1       0.96      0.83      0.89      5612
#            2       0.95      0.91      0.93      4994
#
#     accuracy                           0.89     14394
#    macro avg       0.89      0.90      0.89     14394
# weighted avg       0.91      0.89      0.89     14394

# %%
import pickle

# %%
pickle.dump(model_best, open('model_best.pkl','wb'))

# %%
with open('model_best_pickle','wb') as f:
  pickle.dump(model_best,f)

# %%
with open('model_best_pickle','rb') as f:
  mp=pickle.load(f)

# %%
User_input = input("Entre your text:")

def predict(text):
  input_text = [text]
  text_to_vec = Tfidf_vect.transform(input_text).toarray() 
  prediction = mp.predict(text_to_vec)
  return prediction


output = predict(User_input)
print(output)
if output == 0:
  print('This is hate speech')
elif output == 1:
  print('This is offensive speech')
else:
  print('This is not offensive neither hate speech')
# Out:
# Entre your text:Hitler is good guy
# [1]
# This is offensive speech
